# %%
import os
import pandas as pd
import datetime
import numpy as np

# %%
DATASET_PATH = os.path.join(".", "training_data_cleaned.csv")
data = pd.read_csv(DATASET_PATH)
data.head()
# Out:
#    Unnamed: 0          dt  weekday  year  id_driver id_carrier_number  \
# 0           0  2021-01-20        3  2021      30222          U0117613
# 1           1  2020-03-09        1  2020       4524          C0090405
# 2           2  2020-02-14        5  2020      31164          C0097099
# 3           3  2019-06-10        1  2019       8859          U0097935
# 4           4  2019-12-03        2  2019      18870          U0106560
#
#   dim_carrier_type  dim_carrier_company_name    home_base_city  \
# 0   Owner Operator           Rosas Transport  Santa Fe Springs
# 1            Fleet        Daylight Transport        Long Beach
# 2            Fleet  First Class Transport #8         Hawthorne
# 3   Owner Operator          DTELLIS TRUCKING        Long Beach
# 4   Owner Operator             Z&N Transport       Los Angeles
#
#   home_base_state  ... loads  marketplace_loads_otr marketplace_loads_atlas  \
# 0              CA  ...     4                      1                     253
# 1              CA  ...     6                      0                       0
# 2              CA  ...     1                     29                      82
# 3              CA  ...     1                     25                       6
# 4              CA  ...     4                      1                     233
#
#   marketplace_loads brokerage_loads_otr brokerage_loads_atlas brokerage_loads  \
# 0               254                   0                     3               3
# 1                 0                2671                     0            2671
# 2               111                  30                    19              49
# 3                31                   0                     1               1
# 4               234                   0                     9               9
#
#    total_loads        date recent_date
# 0          257  2021-01-20  2021-02-17
# 1         2671  2020-03-09  2021-02-15
# 2          160  2020-02-14  2020-12-18
# 3           32  2019-06-10  2020-02-16
# 4          243  2019-12-03  2020-02-18
#
# [5 rows x 33 columns]

# %%
# drop unnecessary columns
data = data.drop('Unnamed: 0', axis=1)

# %%
# aggregate columns based on driver ID and keep only most recent entry
data = data.groupby('id_driver').apply(lambda x: x[x['dt'] == x['dt'].max()])

# %% [markdown]
# ## Part 1

# %%
# we convert the column 'most_recent_load_date' into datetime objects in order to calculate the 75th percentile 
most_recent_load_date_datetime = [datetime.datetime.strptime(x, '%Y-%m-%d') for x in data['most_recent_load_date']]
data['most_recent_load_date'] = most_recent_load_date_datetime

# %%
# generate labels based on 75th percentile of 'loads' and 'most_recent_load_date'

labels = []

cutoff_date = data['most_recent_load_date'].quantile(0.75)

# maybe this should be 'total_loads'?
cutoff_loads = data['total_loads'].quantile(0.75)

for index, row in data.iterrows():
    if(row['total_loads'] >= cutoff_loads and row['most_recent_load_date'] >= cutoff_date):
        labels.append(1)
    else:
        labels.append(0)
        
data['label'] = labels

# %%
data['label'].value_counts()
# Out:
# 0    4584
# 1     707
# Name: label, dtype: int64

# %% [markdown]
# ## Part 2

# %%
data = data.drop(['total_loads', 'most_recent_load_date'], axis=1)

# %% [markdown]
# ## Part 3

# %%
data.describe(include='all')
# Out:
#                 dt      weekday         year     id_driver id_carrier_number  \
# count         5291  5291.000000  5291.000000   5291.000000              5291
# unique        1418          NaN          NaN           NaN              2576
# top     2021-02-17          NaN          NaN           NaN          C0094651
# freq           157          NaN          NaN           NaN               214
# mean           NaN     3.329049  2018.713098  17732.668494               NaN
# std            NaN     1.638163     1.434551  11624.261142               NaN
# min            NaN     1.000000  2015.000000     20.000000               NaN
# 25%            NaN     2.000000  2018.000000   8049.500000               NaN
# 50%            NaN     3.000000  2019.000000  15228.000000               NaN
# 75%            NaN     5.000000  2020.000000  29290.500000               NaN
# max            NaN     7.000000  2021.000000  38096.000000               NaN
#
#        dim_carrier_type dim_carrier_company_name home_base_city  \
# count              5291                     5284           5279
# unique                2                     2494            521
# top               Fleet        NFS asset Drayage    Los Angeles
# freq               4085                      214            921
# mean                NaN                      NaN            NaN
# std                 NaN                      NaN            NaN
# min                 NaN                      NaN            NaN
# 25%                 NaN                      NaN            NaN
# 50%                 NaN                      NaN            NaN
# 75%                 NaN                      NaN            NaN
# max                 NaN                      NaN            NaN
#
#        home_base_state carrier_trucks  ...        loads marketplace_loads_otr  \
# count             5279           5291  ...  5291.000000           5291.000000
# unique              40             16  ...          NaN                   NaN
# top                 CA     ["dryvan"]  ...          NaN                   NaN
# freq              4591           3167  ...          NaN                   NaN
# mean               NaN            NaN  ...     1.267624              4.724816
# std                NaN            NaN  ...     0.984093             20.706297
# min                NaN            NaN  ...     1.000000              0.000000
# 25%                NaN            NaN  ...     1.000000              0.000000
# 50%                NaN            NaN  ...     1.000000              1.000000
# 75%                NaN            NaN  ...     1.000000              2.000000
# max                NaN            NaN  ...    26.000000            902.000000
#
#        marketplace_loads_atlas marketplace_loads brokerage_loads_otr  \
# count              5291.000000       5291.000000         5291.000000
# unique                     NaN               NaN                 NaN
# top                        NaN               NaN                 NaN
# freq                       NaN               NaN                 NaN
# mean                  9.245700         13.970516           15.136458
# std                  59.876237         64.959332           99.420194
# min                   0.000000          0.000000            0.000000
# 25%                   0.000000          0.000000            0.000000
# 50%                   0.000000          1.000000            1.000000
# 75%                   0.000000          4.000000            4.000000
# max                1324.000000       1348.000000         4266.000000
#
#        brokerage_loads_atlas  brokerage_loads        date recent_date  \
# count            5291.000000      5291.000000        5291        5291
# unique                   NaN              NaN        1418        1417
# top                      NaN              NaN  2021-02-17  2021-02-17
# freq                     NaN              NaN         157         162
# mean                2.383481        17.519940         NaN         NaN
# std                17.742087       100.784399         NaN         NaN
# min                 0.000000         0.000000         NaN         NaN
# 25%                 0.000000         0.000000         NaN         NaN
# 50%                 0.000000         1.000000         NaN         NaN
# 75%                 0.000000         5.000000         NaN         NaN
# max               371.000000      4266.000000         NaN         NaN
#
#               label
# count   5291.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean       0.133623
# std        0.340279
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [11 rows x 31 columns]

# %%
data
# Out:
#                          dt  weekday  year  id_driver id_carrier_number  \
# id_driver
# 20        12922  2016-06-20        1  2016         20          U0000035
# 26        17520  2015-10-29        4  2015         26          U0000041
# 27        30284  2015-12-09        3  2015         27          U0000042
# 30        61261  2018-12-05        3  2018         30          U0000045
# 31        25636  2016-04-01        5  2016         31          U0000046
# ...                     ...      ...   ...        ...               ...
# 37977     29090  2021-02-11        4  2021      37977          C0098303
# 38039     79531  2021-02-16        2  2021      38039          C0096844
# 38060     43481  2021-02-13        6  2021      38060          C0094651
# 38065     73683  2021-02-17        3  2021      38065          C0094651
# 38096     50073  2021-02-12        5  2021      38096          C0097727
#
#                 dim_carrier_type                 dim_carrier_company_name  \
# id_driver
# 20        12922   Owner Operator                          Mega Fleet Corp
# 26        17520   Owner Operator                                      NaN
# 27        30284   Owner Operator                                      NaN
# 30        61261   Owner Operator                          A & J Transport
# 31        25636   Owner Operator                    lv transportation llc
# ...                          ...                                      ...
# 37977     29090            Fleet  DOLPHIN TRANS, INC. DBA DOLPHIN EXPRESS
# 38039     79531            Fleet                    JT Transportation Inc
# 38060     43481            Fleet                        NFS asset Drayage
# 38065     73683            Fleet                        NFS asset Drayage
# 38096     50073            Fleet                   New opportunities inc
#
#                 home_base_city home_base_state             carrier_trucks  \
# id_driver
# 20        12922       Pasadena              CA                 ["dryvan"]
# 26        17520  Sierra Madre,              CA                 ["dryvan"]
# 27        30284  Sierra Madre,              CA                 ["dryvan"]
# 30        61261     Riverside               CA                 ["reefer"]
# 31        25636            NaN             NaN                 ["dryvan"]
# ...                        ...             ...                        ...
# 37977     29090        Norwalk              CA              ["poweronly"]
# 38039     79531    Los Angeles              CA                 ["dryvan"]
# 38060     43481        Lynwood              CA    ["poweronly", "dryvan"]
# 38065     73683        Lynwood              CA    ["poweronly", "dryvan"]
# 38096     50073    Los Angeles              CA  ["poweronly", "boxtruck"]
#
#                  ...  loads marketplace_loads_otr marketplace_loads_atlas  \
# id_driver        ...
# 20        12922  ...      1                     0                       0
# 26        17520  ...      1                     0                       0
# 27        30284  ...      1                     0                       0
# 30        61261  ...      1                     0                       0
# 31        25636  ...      1                     0                       0
# ...              ...    ...                   ...                     ...
# 37977     29090  ...      2                     0                       0
# 38039     79531  ...      1                     1                       0
# 38060     43481  ...      1                     0                       0
# 38065     73683  ...      2                     0                       0
# 38096     50073  ...      1                     0                       1
#
#                 marketplace_loads brokerage_loads_otr brokerage_loads_atlas  \
# id_driver
# 20        12922                 0                  42                     0
# 26        17520                 0                   1                     0
# 27        30284                 0                  11                     0
# 30        61261                 0                   4                     0
# 31        25636                 0                  15                     0
# ...                           ...                 ...                   ...
# 37977     29090                 0                   0                     2
# 38039     79531                 1                   0                     0
# 38060     43481                 0                   0                     0
# 38065     73683                 0                   0                     0
# 38096     50073                 1                   0                     0
#
#                  brokerage_loads        date recent_date label
# id_driver
# 20        12922               42  2016-06-20  2016-06-20     0
# 26        17520                1  2015-10-29  2015-10-29     0
# 27        30284               11  2015-12-09  2015-12-09     0
# 30        61261                4  2018-12-05  2018-12-05     0
# 31        25636               15  2016-04-01  2016-04-01     0
# ...                          ...         ...         ...   ...
# 37977     29090                2  2021-02-11  2021-02-11     0
# 38039     79531                0  2021-02-16  2021-02-16     0
# 38060     43481                0  2021-02-13  2021-02-13     0
# 38065     73683                0  2021-02-17  2021-02-17     0
# 38096     50073                0  2021-02-12  2021-02-12     0
#
# [5291 rows x 31 columns]
